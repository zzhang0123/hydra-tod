# %% [markdown]
# # Workflow

# %%
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt

from astropy.coordinates import EarthLocation, AltAz, SkyCoord
from astropy.time import Time, TimeDelta
import astropy.units as u
from utils import Leg_poly_proj, view_samples
from flicker_model import sim_noise, flicker_cov

# %% [markdown]
# ## Scan

# %% [markdown]
# Coordinates:
# - MeerKAT Telescope Location:
# 	-	Latitude: -30.7130° S
# 	-	Longitude: 21.4430° E
#
# - Antenna pointing directions:
# 	-	Azimuth
# 	-	Elevation
#
# - Diffuse sky coordinates:
# 	-	RA
# 	-	DEC
#
# - healpy expects (theta, phi) in spherical coordinates:
# 	-	theta = pi/2 - DEC
# 	-	phi = RA

# %%
# Antenna position: Latitude: -30.7130° S; Longitude: 21.4430° E.

# ---- Define telescope location ----
telescope_lat = -30.7130  # MeerKAT latitude in degrees
telescope_lon = 21.4430   # MeerKAT longitude in degrees
telescope_height = 1054    # MeerKAT altitude in meters

location = EarthLocation(lat=telescope_lat * u.deg, lon=telescope_lon * u.deg, height=telescope_height * u.m)


# ---- Define observation parameters ----

# Antenna pointings: Azimuth list and Elevation, in degrees
azimuths = np.linspace(-60, -40, 111)
azimuths = np.concatenate((azimuths, azimuths[1:-1][::-1]))

# Generate 13 repeats of the azimuths
azimuths = np.tile(azimuths, 15)

elevation = 41.7    # Elevation in degrees

# Total length of TOD
ntime = len(azimuths)
print("Total length of TOD: ", ntime)
dtime = 2.0

t_list = np.arange(ntime) * dtime 


plt.figure(figsize=(12, 7))
# Generate the equatorial coordinates of the pointings:
ra_list = []
dec_list = []

plt.subplot(211)
plt.plot(t_list, azimuths)
plt.xlabel('Time (s)')
plt.ylabel('Azimuth (deg)')

plt.subplot(212)
plt.plot(t_list, elevation*np.ones_like(azimuths))
plt.xlabel('Time (s)')
plt.ylabel('Elevation (deg)')
# Out:
# Total length of TOD:  3300
# Text(0, 0.5, 'Elevation (deg)')

# %%
# ---- Define start and end times in SAST ----
start_time_sast = "2024-02-23 19:54:07.397"
#end_time_sast = "2024-02-23 22:12:04.632"

# ---- Convert to UTC (SAST = UTC+2) ----
start_time = Time(start_time_sast) - TimeDelta(2 * u.hour)
#end_time = Time(end_time_sast) - TimeDelta(2 * u.hour)

# ---- Generate time list using numpy.arange ----
dt = 2  # Time step in seconds
time_list = start_time + TimeDelta(t_list, format='sec')

# ---- Print results ----
print(f"Generated {len(time_list)} timestamps.")
# Out:
# Generated 3300 timestamps.

# %%
# ---- Create AltAz coordinate frame ----
altaz_frame = AltAz(obstime=time_list, location=location)

# ---- Convert Az/El to Equatorial (RA, Dec) ----
horizon_coords = SkyCoord(az=azimuths*u.deg, alt=elevation*u.deg, frame=altaz_frame)
equatorial_coords = horizon_coords.transform_to("icrs")

# Convert the equatorial coordinates to pixel indices
# Note: healpy expects (theta, phi) in spherical coordinates
theta_c = np.pi/2 - equatorial_coords.dec.radian  # Convert Dec to theta
phi_c = equatorial_coords.ra.radian               # RA is already phi

# ---- Plot results ----
# Generate a 2D plot of (RA, Dec) coordinates
plt.figure(figsize=(12, 9))
plt.scatter(equatorial_coords.ra, equatorial_coords.dec)
plt.xlabel("Right Ascension (degrees)")
plt.ylabel("Declination (degrees)")
plt.title("Sky Coordinates at Different Times")
plt.show()

# %% [markdown]
# ### Beam setup
#
#  Gaussian Beam (FWHM = 1.1 degrees)
#
# $
# \text{FWHM} = 2 \sigma \sqrt{2 \ln(2)}
# $

# %%
# Define beam parameters
FWHM = 1.1  # Full Width at Half Maximum in degrees
sigma = FWHM / (2 * np.sqrt(2 * np.log(2)))  # Convert FWHM to sigma (degrees)
sigma_rad = np.radians(sigma)  # Convert to radians

# %%
def pixel_angular_size(nside):
    """Compute the angular size (in degrees and arcminutes) of a HEALPix pixel."""
    npix = hp.nside2npix(nside)  # Total number of pixels
    omega_pix = 4 * np.pi / npix  # Pixel area in steradians
    theta_pix_deg = np.sqrt(omega_pix) * (180 / np.pi)  # Approximate pixel width in degrees
    theta_pix_arcmin = theta_pix_deg * 60  # Convert to arcminutes
    return theta_pix_deg, theta_pix_arcmin

# Example usage
nside = 64 # Change NSIDE as needed
theta_deg, theta_arcmin = pixel_angular_size(nside)
print(f"NSIDE = {nside}")
print(f"Pixel angular size: {theta_deg:.6f} degrees ({theta_arcmin:.2f} arcminutes)")
# Out:
# NSIDE = 64
# Pixel angular size: 0.916130 degrees (54.97 arcminutes)

# %%
# Define HEALPix resolution
NSIDE = 64
NPIX = hp.nside2npix(NSIDE)  

# Get HEALPix pixel coordinates (theta, phi)
theta, phi = hp.pix2ang(NSIDE, np.arange(NPIX))

# Generate a initial boolean map with all pixels zero
bool_map = np.zeros(NPIX, dtype=bool)
sum_map = np.zeros(NPIX, dtype=float)
# ---- Set the threshold ----
threshold = 1e-1  # Example: Get all pixels where the value is > 0.5

for ti in range(ntime):
    # Compute angular separation between each pixel and the beam center
    cos_sep = np.cos(theta) * np.cos(theta_c[ti]) + np.sin(theta) * np.sin(theta_c[ti]) * np.cos(phi - phi_c[ti])
    cos_sep = np.clip(cos_sep, -1, 1)  # Ensure within valid range
    angular_sep = np.arccos(cos_sep)  # Separation in radians
    # Compute Gaussian beam response centered at (RA_center, Dec_center)
    beam_map = np.exp(-0.5 * (angular_sep / sigma_rad) ** 2)
    # Normalize the beam (optional, ensures peak = 1)
    beam_map /= np.max(beam_map)
    sum_map += beam_map
    # Get the "or" map of the bool_map and beam_map
    bool_map = np.logical_or(bool_map, beam_map > threshold)

# Count the number of "1" pixels in bool_map
num_pixels = np.sum(bool_map)
print(f"Number of covered pixels: {num_pixels}")

# Get the pixel indices of the "1" pixels:
pixel_indices = np.where(bool_map)[0]

# Save HEALPix map to file
#hp.write_map("gaussian_beam_pointing.fits", beam_map, overwrite=True)

# Plot the beam in Mollweide projection
hp.mollview(sum_map, title=f"Sumed Gaussian Beam", unit="Arbitrary Units")
hp.graticule()
# Out:
# Number of covered pixels: 411

# %%
hp.mollview(bool_map, title=f"Boolean map: masked pixels", unit="Arbitrary Units")
hp.graticule()

# %%
# Get pixels of skymap where corresponding mask value (bool_map) is true 

beam_proj = np.zeros((ntime, num_pixels))

for ti in range(ntime):
    # Compute angular separation between each pixel and the beam center
    cos_sep = np.cos(theta) * np.cos(theta_c[ti]) + np.sin(theta) * np.sin(theta_c[ti]) * np.cos(phi - phi_c[ti])
    cos_sep = np.clip(cos_sep, -1, 1)  # Ensure within valid range
    angular_sep = np.arccos(cos_sep)  # Separation in radians
    # Compute Gaussian beam response centered at (RA_center, Dec_center)
    beam_map = np.exp(-0.5 * (angular_sep / sigma_rad) ** 2)
    # Normalize the beam (optional, ensures peak = 1)
    beam_map /= np.max(beam_map)
    beam_proj[ti] = beam_map[pixel_indices]

norm=np.sum(beam_proj, axis=1)
beam_proj/=norm[:,None]

# %% [markdown]
# ### Sky temperature simulation

# %%
from pygdsm import GlobalSkyModel
gsm = GlobalSkyModel()
gsm.nside =NSIDE
skymap = gsm.generate(500)
true_Tsky = skymap[pixel_indices]
gsm.view(logged=True)

# %% [markdown]
# ### Noise diode setup

# %%
# generate a vector of length ntime, every 10 elements there is a 1, the rest is 0
def generate_vector(ntime):
    vector = np.zeros(ntime)
    for i in range(0, ntime, 10):
        vector[i] = 1
    return vector

ndiode_proj = generate_vector(ntime)

T_ndiode = 10.0

# %% [markdown]
# ### Receiver temperature

# %%
rec_proj = Leg_poly_proj(4, t_list)[:,1:]
rec_params=np.array([1, 0.5, 1])
plt.title("Receiver temperature")
plt.plot(rec_proj @ rec_params)

# %% [markdown]
# ### Gain and noise setup

# %%
from numpy.linalg import cholesky

gain_proj = Leg_poly_proj(4, t_list)
gain_params=np.array([2, 0.5, 1.5, 0.5])*2
mu0 = np.sin(2*np.pi*0.1*t_list)
gains = gain_proj @ gain_params + mu0

f0, fc, alpha = 1e-4, 2e-5, 2.0
sigma_2 = 1/(4e5)

noise = sim_noise(f0, fc, alpha, t_list, n_samples=1, white_n_variance=sigma_2)[0]
covmat = flicker_cov(t_list, f0, fc, alpha, white_n_variance=sigma_2, only_row_0=False)
# invert the symmetric matrix, covmat
Ninv = np.linalg.inv(covmat)

aux_mat = cholesky(Ninv, upper=True)
white_noise = aux_mat @ noise

# Check if white noise is white: compare PSD of corr_noise and white_noise
psd_corr = np.abs(np.fft.rfft(noise))**2
psd_white = np.abs(np.fft.rfft(white_noise))**2
freqs = np.fft.rfftfreq(ntime, d=2)
# plot psd
plt.loglog(freqs, psd_corr, label='corr_noise')
plt.loglog(freqs, psd_white, label='white_noise')
ex_noise = np.random.randn(ntime)
psd_ex = np.abs(np.fft.rfft(ex_noise))**2
plt.loglog(freqs, psd_ex, label='ex_noise')

plt.legend()

# %%
from Tsys_sampler import Tsys_model

TOD_ndiode = T_ndiode*ndiode_proj
TOD_rec = rec_proj @ rec_params
Tsys_sim = Tsys_model([beam_proj, rec_proj, ndiode_proj], [true_Tsky, rec_params, T_ndiode])
TOD_sim = Tsys_sim * (1+noise) * gains

# %% [markdown]
# Generate a sequence of time-ordered data for a scan of a receiver.

# %% [markdown]
# ## Noise Parameter Sampler

# %%
from noise_sampler import noise_params_sampler, flicker_likeli_func
from mcmc_sampler import mcmc_sampler

# %%
logn_params = [np.log10(f0), np.log10(fc), alpha]
boundaries = [[-12.,0.], [-12.,0.], [1.01,5.0]]
log_likeli = flicker_likeli_func(t_list, TOD_sim, gains, Tsys_sim, wnoise_var=2.5e-6, boundaries=None)
noise_samples_Jeff = mcmc_sampler(log_likeli, logn_params, p_std=0.05, 
                    nsteps=50,  # steps for each chain
                    n_samples=1,
                    prior_func=None,
                    num_Jeffrey=False,
                    return_sampler=False)

# logn_params = np.log10(f0), np.log10(fc), alpha
# view_samples(noise_samples_Jeff, logn_params)
# Out:
# 100%|██████████| 50/50 [00:44<00:00,  1.13it/s]

# %%
# noise_samples_no_prior = noise_params_sampler(t_list, TOD_sim, gains, Tsys_sim, 
#                         sigma_2,
#                         nwalkers=6, 
#                         nsteps=100, 
#                         n_samples=300,
#                         log_scale=True, 
#                         prior_func=None,
#                         return_sampler=False)

# noise_samples = noise_samples_no_prior
# # Calculate statistics
# mean = np.mean(noise_samples, axis=0)
# std = np.std(noise_samples, axis=0)

# # Create subplots for four parameters
# fig, axes = plt.subplots(1, 3, figsize=(15, 6))
# axes = axes.ravel()

# logn_params = np.log10(f0), np.log10(fc), alpha
# params_names = ['log(f0)', 'log(fc)', 'alpha']
# for i in range(3):
#     # Plot histogram of samples for each parameter
#     axes[i].hist(noise_samples[:, i], bins=50, density=True, alpha=0.6, label='Samples')
    
#     # Plot true value line
#     axes[i].axvline(x=logn_params[i], color='r', linestyle='-', label='True Value', linewidth=2, alpha=0.7)
    
#     # Plot mean value line
#     axes[i].axvline(x=mean[i], color='g', linestyle='--', label='Mean')
    
#     # Add labels and title
#     axes[i].set_xlabel('Coefficient')
#     axes[i].set_ylabel('Density')
#     axes[i].set_title(f'Parameter {params_names[i]}')
#     axes[i].legend()
    
#     # Print numerical comparison for each parameter
#     print(f"\nGain Parameter {i+1}:")
#     print(f"True value: {logn_params[i]:.6f}")
#     print(f"Mean sampled: {mean[i]:.6f}")
#     print(f"Standard deviation: {std[i]:.6f}")

# plt.suptitle('Comparison of True Values, Mean for Noise Parameters (No Prior) (300 samples)')

# plt.tight_layout()
# plt.show()

# %%
noise_samples_Jeff.shape
# Out:
# (3,)

# %% [markdown]
# ## Gain Sampler Test

# %% [markdown]
# To test the gain sampler, we sample gain coefficients with given noise parameters and system parameters.

# %% [markdown]
# Iterative Generalised Least Squares (GLS) procedure.

# %%
from gain_sampler import gain_coeff_sampler

gain_samples = gain_coeff_sampler(TOD_sim, 
                    gain_proj, 
                    Tsys_sim, 
                    covmat, 
                    mu=mu0,
                    n_samples=4000,
                    tol=1e-14,
                    prior_cov_inv=None, 
                    prior_mean=None, 
                    solver=None)

view_samples(gain_samples, gain_params)
# Out:
#  Parameter 1:
# True value: 4.000000
# Mean sampled: 4.164120
# Standard deviation: 1.700848
# Relative error: 4.10%
#
#  Parameter 2:
# True value: 1.000000
# Mean sampled: 1.042384
# Standard deviation: 0.559895
# Relative error: 4.24%
#
#  Parameter 3:
# True value: 3.000000
# Mean sampled: 3.108074
# Standard deviation: 1.288544
# Relative error: 3.60%
#
#  Parameter 4:
# True value: 1.000000
# Mean sampled: 1.052817
# Standard deviation: 0.464693
# Relative error: 5.28%

# %% [markdown]
# ## System temperature sampler

# %%
from Tsys_sampler import Tsys_coeff_sampler, overall_operator

TOD_ndiode = T_ndiode*ndiode_proj

Tsys_proj = overall_operator([beam_proj, rec_proj])


Tsys_params = Tsys_coeff_sampler(TOD_sim, 
                       gains, 
                       Tsys_proj, 
                       covmat, 
                       n_samples=100,
                       mu=TOD_ndiode,
                       tol=1e-17,
                       prior_cov_inv=None, 
                       prior_mean=None, 
                       solver=None)

# %%
Tsky_samples = Tsys_params[:,:num_pixels]
Tsky_mean = np.mean(Tsky_samples, axis=0)
Tsky_std = np.std(Tsky_samples, axis=0)
#Trec_samples = Tsys_params[:,num_pixels:]
#view_samples(Trec_samples, rec_params)

# %%
# Compare true Tsky and sampled Tsky

plt.figure(figsize=(10, 6))
plt.plot(true_Tsky, label='True Tsky')
# Plot the mean of the samples, with error bars being the standard deviation
plt.errorbar(np.arange(len(true_Tsky)), Tsky_mean, yerr=Tsky_std, label='Sampled Tsky')
plt.ylim(5, 12)
plt.legend()

# %%
plt.plot(Tsky_std)

# %% [markdown]
# ## Test the full Gibbs sampler

# %%
from full_Gibbs_sampler import full_Gibbs_sampler_singledish
# Out:
# Traceback (most recent call last):
#
#   File ~/anaconda3/envs/test/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[24], line 1
#     from full_Gibbs_sampler import full_Gibbs_sampler_singledish
#
#   File ~/PythonProjects/flicker/full_Gibbs_sampler.py:50
#     init_noise_params
#     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
p_gain_samples, p_sys_samples, p_noise_samples = full_Gibbs_sampler_singledish(TOD_sim, 
                                  t_list,
                                  TOD_ndiode,
                                  Tsys_proj,
                                  gain_proj,
                                  np.hstack((true_Tsky, rec_params)), 
                                  logn_params, 
                                  wnoise_var=2.5e-6,
                                  Tsys_prior_cov_inv=None,
                                  Tsys_prior_mean=None,
                                  gain_prior_cov_inv=None,
                                  gain_prior_mean=None,
                                  noise_prior_func=None,
                                  n_samples=2,
                                  tol=1e-15,
                                  linear_solver=None,)
# Out:
# 100%|██████████| 50/50 [00:44<00:00,  1.11it/s]
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.06599e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.15151e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.04457e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.48684e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.36e-23): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.57494e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.27393e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.33634e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.82532e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.34383e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.9113e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.56228e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.22474e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.14388e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.51256e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.04942e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.97203e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.09101e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.34179e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.48824e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.79192e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.11061e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.85218e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.85256e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.56037e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.67121e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.98331e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.67995e-23): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.60801e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.55575e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.52667e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.94691e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.68939e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.08613e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.06703e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.8354e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.90779e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.3287e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.44878e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.01062e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.6498e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.05586e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.39098e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.48706e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.37247e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.42102e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.53333e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.40714e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.34572e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.69904e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.53717e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.02464e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.94097e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.48424e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.27484e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.73799e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.21831e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.13691e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.59217e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.93006e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.75482e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.48586e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.69471e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.17812e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.86826e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.51054e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.67823e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.98534e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.63784e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.24378e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.38129e-23): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.20585e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.0985e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.79697e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.60567e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.33708e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.26939e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.10154e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.78512e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.43211e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.28469e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.17738e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.55932e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.85947e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.299e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.45905e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.22888e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.64007e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.36752e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.14411e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.13752e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.26895e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.07412e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.62918e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.27331e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.58671e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.86441e-20): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.82929e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.4357e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.35494e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:183: LinAlgWarning: Ill-conditioned matrix (rcond=1.05874e-20): result may not be accurate.
#   p_samples[i,:] = solve(A, b, assume_a='sym')
#  40%|████      | 20/50 [00:18<00:27,  1.10it/s]/Users/user/PythonProjects/flicker/noise_sampler.py:26: RuntimeWarning: invalid value encountered in log
#   terms = np.log(1 - k**2)
# /Users/user/PythonProjects/flicker/noise_sampler.py:28: RuntimeWarning: invalid value encountered in log
#   return n * np.log(a0) + np.dot(factors, terms)
# 100%|██████████| 50/50 [00:44<00:00,  1.11it/s]
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.44831e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.04062e-21): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.2395e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.6461e-22): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.3346e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.18156e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.51016e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.17457e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.61994e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.93826e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.69009e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.46394e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.71071e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.05391e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.19938e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.16222e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.77109e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.00536e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.91029e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.77744e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.54178e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.78098e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.77353e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.8299e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.69273e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.80686e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.26742e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.16299e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.40252e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.71382e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.29892e-29): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.01832e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.02232e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.84768e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.60627e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.17345e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.00321e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.27677e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.56162e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.95956e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.09831e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.99529e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.38519e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.29027e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.96982e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.04731e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.67816e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.64869e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.90643e-23): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.06918e-23): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.11037e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.98516e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.41241e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.1341e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.35705e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.27849e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.80529e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.46734e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.34222e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.30321e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.15705e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.32127e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.28542e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.41492e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.24958e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.96556e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.3787e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.38589e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.17711e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.35745e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.09224e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.49209e-29): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.34466e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.85035e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=6.2509e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.24389e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.21231e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.26579e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.86995e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.07196e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=3.34291e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.79331e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.81364e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.63986e-25): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.2571e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.962e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.67707e-28): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.66613e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.13441e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.1729e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.06927e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.45446e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=4.9834e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.13836e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=9.35335e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=5.21428e-27): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=7.14344e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=1.71265e-24): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=2.2874e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:52: LinAlgWarning: Ill-conditioned matrix (rcond=8.71709e-26): result may not be accurate.
#   p_new = solve(UTSigma_invU, UTSigma_invD, assume_a='sym')
# /Users/user/PythonProjects/flicker/linear_sampler.py:183: LinAlgWarning: Ill-conditioned matrix (rcond=5.74745e-26): result may not be accurate.
#   p_samples[i,:] = solve(A, b, assume_a='sym')
