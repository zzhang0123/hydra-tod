# %% [markdown]
# # Workflow

# %%
import numpy as np
import healpy as hp
import matplotlib.pyplot as plt
import sys

sys.path.append('../hydra_TOD/')

from astropy.coordinates import EarthLocation, AltAz, SkyCoord
from astropy.time import Time, TimeDelta
import astropy.units as u
from utils import Leg_poly_proj, view_samples
from flicker_model import sim_noise, flicker_cov
from simulation import *

# %% [markdown]
# ## A. Simulation

# %%
nside = 64

# %% [markdown]
# ### 1. Define the two scans (rising and setting)
# Tsky parameters and operators

# %%
# Get the timestream of beam centers (theta_c, phi_c) for each scan
_, theta_c_setting, phi_c_setting = sim_MeerKAT_scan(elevation=41.5, az_s=-60.3, az_e=-42.3, start_time_utc="2019-04-23 20:41:56.397")
bool_map_setting, integrated_beam_setting = stacked_beam_map(theta_c_setting, 
                                       phi_c_setting, 
                                       FWHM=1.1, 
                                       NSIDE=nside, 
                                       threshold = 0.0111) # This threshold cut off the beam directions outside the 3sigma region.


t_list, theta_c_rising, phi_c_rising = sim_MeerKAT_scan(elevation=40.5, az_s=43.7, az_e=61.7, start_time_utc="2019-03-30 17:19:02.397")
bool_map_rising, integrated_beam_rising = stacked_beam_map(theta_c_rising, 
                                                            phi_c_rising, 
                                                            FWHM=1.1, 
                                                            NSIDE=nside, 
                                                            threshold = 0.0111)

# %%
full_bool_map, pixel_indices = reduce_bool_maps_LOR([bool_map_setting, bool_map_rising])
integrated_beam = integrated_beam_setting + integrated_beam_rising

Tsky_operator_setting = generate_Tsky_proj(full_bool_map, theta_c_setting, phi_c_setting, FWHM=1.1)
Tsky_operator_rising = generate_Tsky_proj(full_bool_map, theta_c_rising, phi_c_rising, FWHM=1.1)

# %%
def sky_vector(pixel_indices, freq, Nside=64, sky_model=None):
    if sky_model is None:
        from pygdsm import GlobalSkyModel
        gsm = GlobalSkyModel()
        skymap = gsm.generate(freq)
    else:
        skymap = sky_model(freq)
    skymap = hp.ud_grade(skymap, nside_out=Nside)
    ptsrc = np.load("gleam_nside512_K_allsky_408MHz.npy")
    ptsrc_map = hp.ud_grade(ptsrc, nside_out=Nside)
    skymap = skymap + ptsrc_map
    return skymap[pixel_indices]

sky_params = sky_vector(pixel_indices, 408, Nside=nside, sky_model=None)
print("Number of pixels: ", len(pixel_indices))
# Out:
# Number of pixels:  473

# %% [markdown]
# ### 2. Define Tdiode and Trec

# %%
# generate a vector of length ntime, every 10 elements there is a 1, the rest is 0
def generate_vector(ntime):
    vector = np.zeros(ntime)
    for i in range(0, ntime, 10):
        vector[i] = 1
    return vector

ntime = len(t_list)
ndiode_proj = generate_vector(ntime)

nd_rec_operator = np.zeros((ntime, 2))
nd_rec_operator[:, 0] = ndiode_proj    # The noise diode part
nd_rec_operator[:, 1:] = Leg_poly_proj(1, t_list) # The Legendre polynomial (receiver temperature and all) part

T_ndiode = 10.0
rec_params=np.array([4]) # The receiver temperature and all
nd_rec_params = np.zeros(2)
nd_rec_params[0] = T_ndiode
nd_rec_params[1:] = rec_params

plt.title("Receiver + Tnd temperature")
plt.plot(nd_rec_operator @ nd_rec_params)

# %% [markdown]
# ### 3. Define Gain and Noise

# %%
gain_proj = Leg_poly_proj(4, t_list)

gain_params = np.load('outputs/sim1/gain_params.npz')
gain_params_setting = gain_params['gain_params_setting']
gain_params_rising = gain_params['gain_params_rising']

gains_setting = gain_proj @ gain_params_setting
gains_rising  = gain_proj @ gain_params_rising

# %%
dtime = 2
fc = (1/ntime/dtime)*2*np.pi
logfc = np.log10(fc)
alpha = 2.0
logf0_list=[-4.874571109426952, -3.874259892646189, -2.901434432609383] 
# Corresponding to knee frequencies: 0.001. 0.01, 0.1
sigma_2 = 1/(4e5)

f0 = 10**logf0_list[0]

noise_setting = sim_noise(f0, fc, alpha, t_list, white_n_variance=sigma_2)
noise_rising = sim_noise(f0, fc, alpha, t_list, white_n_variance=sigma_2)

# %%
Tsys_setting = Tsky_operator_setting @ sky_params + nd_rec_operator @ nd_rec_params 
TOD_setting = Tsys_setting * (1+noise_setting) * gains_setting

Tsys_rising = Tsky_operator_rising @ sky_params + nd_rec_operator @ nd_rec_params 
TOD_rising = Tsys_rising * (1+noise_rising) * gains_rising

# %% [markdown]
# ## B. Sampling

# %%
def reduce_bool_maps_LAND(bool_maps):
    """
    Reduce a list of boolean maps using the "logical and" operation.
    """
    reduced_map = np.logical_and.reduce(bool_maps)
    # Get the pixel indices of the "1" pixels:
    pixel_indices = np.where(reduced_map)[0]
    return reduced_map, pixel_indices

# %%
# Convert theta/phi coordinates to HEALPix pixels
pixels_c_setting = [hp.ang2pix(nside=nside, theta=theta, phi=phi)
          for theta, phi in zip(theta_c_setting, phi_c_setting)]
bool_map_c_setting = np.zeros(hp.nside2npix(nside))
bool_map_c_setting[pixels_c_setting] = 1

# Convert theta/phi coordinates to HEALPix pixels
# pixels_c_rising = [hp.ang2pix(nside=nside, theta=theta, phi=phi)
#           for theta, phi in zip(theta_c_rising, phi_c_rising)]
# bool_map_c_rising = np.zeros(hp.nside2npix(nside))
# bool_map_c_rising[pixels_c_rising] = 1

# LAND_bool_map, shared_pixel_indices = reduce_bool_maps_LAND([bool_map_c_setting, bool_map_c_rising])
# shared_indices = [list(pixel_indices).index(item) for item in shared_pixel_indices]

# # For a 1D array 'integrated_beam_setting'
# n_cal_pixs=1
# top_20_beam_indices = np.argpartition(integrated_beam[pixel_indices], -20)[-20:]
# top_n_sky_indices = np.argpartition(sky_params[top_20_beam_indices], -n_cal_pixs)[-n_cal_pixs:]
# calibration_indices = top_20_beam_indices[top_n_sky_indices]

# For a 1D array 'integrated_beam_setting'
n_cal_pixs= 5
top_200_beam_indices = np.argpartition(integrated_beam[pixel_indices], -200)[-200:]
calibration_indices = [top_200_beam_indices[int(i* 200 / n_cal_pixs)] for i in range(n_cal_pixs)]

# %%
init_Tsys_params = np.hstack([sky_params, nd_rec_params, nd_rec_params])
init_noise_params = [-4.8, 2.]

gain_prior_cov_inv = np.eye(4)*0.5
gain_prior_cov_inv[0, 0] = 2.
gain_prior_mean = np.array([6., 0., 0., 0.])

Tsky_prior_cov_inv = np.ones_like(sky_params)*0.2
Tsky_prior_cov_inv[calibration_indices] = 1e20

Trec_prior_cov = np.zeros_like(nd_rec_params)
Trec_prior_cov[0] = 10.
Trec_prior_cov_inv = [Trec_prior_cov, Trec_prior_cov]

def log_prior_noise(params):
    _, alpha_est = params
    return -1e10 * (alpha_est - alpha)**4

# %%
# class TOD_sim:
#     def __init__(self, t_list, theta_c, phi_c, 
#                  TOD, gain_proj, Tsky_proj, nd_rec_proj,
#                  ):
#         self.t_list = None
#         self.theta_c = None
#         self.phi_c = None

# %%
from full_Gibbs_sampler import full_Gibbs_sampler_multi_TODS_v2

Tsys_samples, all_gain_samples, all_noise_samples = \
    full_Gibbs_sampler_multi_TODS_v2([TOD_setting, TOD_rising],
                                    [t_list, t_list],
                                    [gain_proj, gain_proj],
                                    [Tsky_operator_setting, Tsky_operator_rising],
                                    [nd_rec_operator, nd_rec_operator],
                                    init_Tsys_params,
                                    init_noise_params, 
                                    [logfc, logfc],
                                    num_Jeffrey=False,
                                    wnoise_var=2.5e-6,
                                    Tsky_prior_cov_inv=Tsky_prior_cov_inv,
                                    Tsky_prior_mean=sky_params,
                                    local_Trec_prior_cov_inv_list=Trec_prior_cov_inv,
                                    local_Trec_prior_mean_list=[nd_rec_params, nd_rec_params],
                                    local_gain_prior_cov_inv_list=[gain_prior_cov_inv,gain_prior_cov_inv],
                                    local_gain_prior_mean_list=[gain_prior_mean,gain_prior_mean],
                                    local_noise_prior_func_list=[log_prior_noise, log_prior_noise],
                                    n_samples=300,
                                    tol=1e-12)
# Out:
# Rank: 0, local id: 0, gain_sample 0: [6.31170733 0.42026513 0.26237014 0.05532641]
# Rank: 0, local id: 0, noise_sample 0: [-5.0435163   2.00342786]
# Rank: 0, local id: 1, gain_sample 0: [6.29072888 0.95777403 0.64467216 0.92293162]
# Rank: 0, local id: 1, noise_sample 0: [-4.91736557  2.00334875]
# Reached max iterations with fractional norm error 0.00019326863199188558.
# Rank: 0, local id: 0, gain_sample 1: [6.31126444 0.41978852 0.26176819 0.05612575]
# Rank: 0, local id: 0, noise_sample 1: [-5.69928623  1.99974487]
# Rank: 0, local id: 1, gain_sample 1: [6.29051671 0.95736042 0.6440781  0.92447536]
# Rank: 0, local id: 1, noise_sample 1: [-5.47068218  2.00326326]
# Reached max iterations with fractional norm error 0.0016250700932268455.
# Rank: 0, local id: 0, gain_sample 2: [6.31071895 0.41991456 0.26126979 0.05724593]
# Rank: 0, local id: 0, noise_sample 2: [-5.10794948  1.99901049]
# Rank: 0, local id: 1, gain_sample 2: [6.29108855 0.95744932 0.64573123 0.92529794]
# Rank: 0, local id: 1, noise_sample 2: [-4.84108279  2.00148319]
# Reached max iterations with fractional norm error 0.0025916392294396784.
# Rank: 0, local id: 0, gain_sample 3: [6.31096096 0.41945948 0.26444084 0.05565015]
# Rank: 0, local id: 0, noise_sample 3: [-4.82746012  2.00458751]
# Rank: 0, local id: 1, gain_sample 3: [6.29081638 0.95600955 0.64357147 0.92615002]
# Rank: 0, local id: 1, noise_sample 3: [-4.913065    1.99837021]
# Reached max iterations with fractional norm error 0.006789044508887192.
# Rank: 0, local id: 0, gain_sample 4: [6.31086449 0.41932178 0.26389062 0.05563455]
# Rank: 0, local id: 0, noise_sample 4: [-5.09194951  1.99807552]
# Rank: 0, local id: 1, gain_sample 4: [6.29121624 0.95768992 0.64609163 0.92715843]
# Rank: 0, local id: 1, noise_sample 4: [-4.64392504  2.00078844]
# Reached max iterations with fractional norm error 0.00027967328635732.
# Rank: 0, local id: 0, gain_sample 5: [6.3112292  0.41980886 0.26409611 0.058629  ]
# Rank: 0, local id: 0, noise_sample 5: [-4.64559761  2.00121382]
# Rank: 0, local id: 1, gain_sample 5: [6.29116914 0.96037182 0.64642857 0.9277946 ]
# Rank: 0, local id: 1, noise_sample 5: [-4.70654366  1.99860777]
# Reached max iterations with fractional norm error 0.0008598610262579858.
# Rank: 0, local id: 0, gain_sample 6: [6.31128209 0.42078006 0.26344071 0.05787716]
# Rank: 0, local id: 0, noise_sample 6: [-4.80950095  1.99701668]
# Rank: 0, local id: 1, gain_sample 6: [6.29133464 0.95862914 0.64535443 0.92792244]
# Rank: 0, local id: 1, noise_sample 6: [-4.88202035  2.00029796]
# Reached max iterations with fractional norm error 0.00048375479953361643.
# Rank: 0, local id: 0, gain_sample 7: [6.31123949 0.42103798 0.26122122 0.05580938]
# Rank: 0, local id: 0, noise_sample 7: [-4.68631938  1.99600656]
# Rank: 0, local id: 1, gain_sample 7: [6.29174328 0.95901024 0.64697262 0.92919404]
# Rank: 0, local id: 1, noise_sample 7: [-4.83293065  2.0031166 ]
# Reached max iterations with fractional norm error 0.00011959485728668543.
# Rank: 0, local id: 0, gain_sample 8: [6.31158997 0.42050258 0.26116561 0.05428801]
# Rank: 0, local id: 0, noise_sample 8: [-4.54101431  2.00151003]
# Rank: 0, local id: 1, gain_sample 8: [6.29142058 0.95779322 0.64695567 0.92943891]
# Rank: 0, local id: 1, noise_sample 8: [-5.13901561  1.99957223]
# Reached max iterations with fractional norm error 6.886244543562521e-05.
# Rank: 0, local id: 0, gain_sample 9: [6.31194415 0.42106683 0.26254658 0.05711503]
# Rank: 0, local id: 0, noise_sample 9: [-4.56871671  1.99928107]
# Rank: 0, local id: 1, gain_sample 9: [6.29086748 0.95711586 0.64651527 0.92869448]
# Rank: 0, local id: 1, noise_sample 9: [-5.16660507  2.00045343]
# Reached max iterations with fractional norm error 0.008485398823935774.
# Rank: 0, local id: 0, gain_sample 10: [6.31147885 0.42014367 0.25887157 0.05501067]
# Rank: 0, local id: 0, noise_sample 10: [-4.89765587  2.00143613]
# Rank: 0, local id: 1, gain_sample 10: [6.29039018 0.95756766 0.64567332 0.92787035]
# Rank: 0, local id: 1, noise_sample 10: [-4.51344116  2.00146953]
# Reached max iterations with fractional norm error 0.000984810967449488.
# Rank: 0, local id: 0, gain_sample 11: [6.31103437 0.41997518 0.26094261 0.05466414]
# Rank: 0, local id: 0, noise_sample 11: [-4.98587089  1.99944827]
# Rank: 0, local id: 1, gain_sample 11: [6.29023685 0.95902669 0.64496925 0.92756289]
# Rank: 0, local id: 1, noise_sample 11: [-4.94430815  1.99846225]
# Reached max iterations with fractional norm error 0.004028893818689706.
# Rank: 0, local id: 0, gain_sample 12: [6.3112947  0.41986344 0.26137538 0.05526097]
# Rank: 0, local id: 0, noise_sample 12: [-4.87691956  2.00190143]
# Rank: 0, local id: 1, gain_sample 12: [6.29025295 0.95883443 0.64658047 0.92649747]
# Rank: 0, local id: 1, noise_sample 12: [-4.66199331  2.00291412]
# Reached max iterations with fractional norm error 0.00013712011462981412.
# Rank: 0, local id: 0, gain_sample 13: [6.31095705 0.41976212 0.26130171 0.05510378]
# Rank: 0, local id: 0, noise_sample 13: [-4.72701464  1.99734451]
# Rank: 0, local id: 1, gain_sample 13: [6.2902372  0.95713745 0.64508317 0.92669595]
# Rank: 0, local id: 1, noise_sample 13: [-4.82376428  2.00128029]
# Reached max iterations with fractional norm error 0.0030005339857227813.
# Rank: 0, local id: 0, gain_sample 14: [6.31155593 0.42053368 0.26324638 0.0569094 ]
# Rank: 0, local id: 0, noise_sample 14: [-5.07979951  2.00061232]
# Rank: 0, local id: 1, gain_sample 14: [6.29064829 0.95910291 0.64685886 0.92644603]
# Rank: 0, local id: 1, noise_sample 14: [-5.07654916  1.9978539 ]
# Reached max iterations with fractional norm error 0.0014839636587357795.
# Rank: 0, local id: 0, gain_sample 15: [6.31159163 0.42032316 0.26285175 0.05889461]
# Rank: 0, local id: 0, noise_sample 15: [-4.74210186  1.99861759]
# Converged in 53 iterations.
# Rank: 0, local id: 1, gain_sample 15: [6.29051717 0.9592291  0.6467362  0.9279302 ]
# Rank: 0, local id: 1, noise_sample 15: [-4.7766812   1.99903008]
# Reached max iterations with fractional norm error 0.003074835732744923.
# Rank: 0, local id: 0, gain_sample 16: [6.31188788 0.42038277 0.26283833 0.05573741]
# Rank: 0, local id: 0, noise_sample 16: [-4.84093115  2.00025084]
# Rank: 0, local id: 1, gain_sample 16: [6.29044489 0.95794265 0.64894932 0.92757299]
# Rank: 0, local id: 1, noise_sample 16: [-4.86719072  2.00094268]
# Reached max iterations with fractional norm error 0.005074254554415228.
# Rank: 0, local id: 0, gain_sample 17: [6.31164689 0.41830015 0.26206291 0.0552903 ]
# Rank: 0, local id: 0, noise_sample 17: [-4.78570352  2.00019017]
# Rank: 0, local id: 1, gain_sample 17: [6.29023475 0.95746936 0.64959186 0.92826719]
# Rank: 0, local id: 1, noise_sample 17: [-4.74317691  1.99873155]
# Reached max iterations with fractional norm error 0.00020514111657468257.
# Converged in 13 iterations.
# Rank: 0, local id: 0, gain_sample 18: [6.31176944 0.41699335 0.26425892 0.05558233]
# Rank: 0, local id: 0, noise_sample 18: [-4.87764495  2.00221263]
# Rank: 0, local id: 1, gain_sample 18: [6.28983233 0.95708085 0.64503354 0.9247182 ]
# Rank: 0, local id: 1, noise_sample 18: [-4.97882458  2.00026689]
# Reached max iterations with fractional norm error 0.007640736755943123.
# Rank: 0, local id: 0, gain_sample 19: [6.31168391 0.41756518 0.2595712  0.05603215]
# Rank: 0, local id: 0, noise_sample 19: [-4.61922438  2.00051191]
# Rank: 0, local id: 1, gain_sample 19: [6.29018503 0.95624195 0.64451564 0.92515653]
# Rank: 0, local id: 1, noise_sample 19: [-4.76781541  1.99962839]
# Reached max iterations with fractional norm error 0.0003347059216401981.
# Rank: 0, local id: 0, gain_sample 20: [6.31206458 0.41929117 0.26491933 0.05504681]
# Rank: 0, local id: 0, noise_sample 20: [-4.63218088  2.0028122 ]
# Rank: 0, local id: 1, gain_sample 20: [6.29021864 0.95707611 0.64572107 0.93036772]
# Rank: 0, local id: 1, noise_sample 20: [-4.66503846  1.99979939]
# Reached max iterations with fractional norm error 0.0007511198229427368.
# Rank: 0, local id: 0, gain_sample 21: [6.31262065 0.42070032 0.26456706 0.05436077]
# Rank: 0, local id: 0, noise_sample 21: [-4.83618594  2.009626  ]
# Rank: 0, local id: 1, gain_sample 21: [6.28990754 0.9566496  0.64467305 0.92722417]
# Rank: 0, local id: 1, noise_sample 21: [-4.64764938  2.00123256]
# Reached max iterations with fractional norm error 0.007736446620607537.
# Rank: 0, local id: 0, gain_sample 22: [6.31199821 0.41937818 0.26126376 0.05399662]
# Rank: 0, local id: 0, noise_sample 22: [-4.97611744  2.00033099]
# Rank: 0, local id: 1, gain_sample 22: [6.29016181 0.95908526 0.64543542 0.92920322]
# Rank: 0, local id: 1, noise_sample 22: [-4.71418202  2.00370911]
# Reached max iterations with fractional norm error 0.0012936625855024578.
# Rank: 0, local id: 0, gain_sample 23: [6.31220559 0.41974889 0.262775   0.05510274]
# Rank: 0, local id: 0, noise_sample 23: [-4.82002913  1.9999436 ]
# Rank: 0, local id: 1, gain_sample 23: [6.2900606  0.95695978 0.64311871 0.92872835]
# Rank: 0, local id: 1, noise_sample 23: [-4.69543534  1.9996644 ]
# Reached max iterations with fractional norm error 0.0007532732718024605.
# Rank: 0, local id: 0, gain_sample 24: [6.31259196 0.42168326 0.26492582 0.05591413]
# Rank: 0, local id: 0, noise_sample 24: [-4.73684899  1.99807799]
# Rank: 0, local id: 1, gain_sample 24: [6.28930507 0.95898005 0.64171525 0.92232645]
# Rank: 0, local id: 1, noise_sample 24: [-4.57998221  2.00117371]
# Reached max iterations with fractional norm error 0.003584011956719737.
# Rank: 0, local id: 0, gain_sample 25: [6.31282387 0.42243903 0.26599649 0.05285315]
# Rank: 0, local id: 0, noise_sample 25: [-4.7103741   2.00021183]
# Rank: 0, local id: 1, gain_sample 25: [6.28968007 0.95714136 0.64418071 0.92589434]
# Rank: 0, local id: 1, noise_sample 25: [-4.63047805  1.9997842 ]
# Reached max iterations with fractional norm error 0.001737355366791641.
# Rank: 0, local id: 0, gain_sample 26: [6.31257443 0.42050997 0.26397829 0.05451595]
# Rank: 0, local id: 0, noise_sample 26: [-4.78701929  1.99829253]
# Rank: 0, local id: 1, gain_sample 26: [6.28945037 0.95760015 0.64437312 0.92961366]
# Rank: 0, local id: 1, noise_sample 26: [-4.68954434  1.99840834]
# Reached max iterations with fractional norm error 0.0009669015973175691.
# Rank: 0, local id: 0, gain_sample 27: [6.31264357 0.42152946 0.26493189 0.05561239]
# Rank: 0, local id: 0, noise_sample 27: [-4.72162828  2.00196587]
# Rank: 0, local id: 1, gain_sample 27: [6.28978887 0.95658759 0.64535884 0.92756474]
# Rank: 0, local id: 1, noise_sample 27: [-5.12624127  2.00168413]
# Reached max iterations with fractional norm error 0.0045842414053619.
# Rank: 0, local id: 0, gain_sample 28: [6.31216042 0.41965629 0.26168295 0.05497912]
# Rank: 0, local id: 0, noise_sample 28: [-4.99818733  2.00110891]
# Rank: 0, local id: 1, gain_sample 28: [6.28983422 0.95752063 0.64622163 0.92713999]
# Rank: 0, local id: 1, noise_sample 28: [-5.66282102  2.00133975]
# Reached max iterations with fractional norm error 0.003236975337016207.
# Rank: 0, local id: 0, gain_sample 29: [6.31203107 0.41973828 0.2616007  0.05653082]
# Rank: 0, local id: 0, noise_sample 29: [-4.91076787  1.99905983]
# Rank: 0, local id: 1, gain_sample 29: [6.29008323 0.95729085 0.64648755 0.92684906]
# Rank: 0, local id: 1, noise_sample 29: [-5.33904544  1.99751005]
# Reached max iterations with fractional norm error 7.136488329580347e-05.
# Rank: 0, local id: 0, gain_sample 30: [6.31227849 0.42005891 0.26388127 0.05611131]
# Rank: 0, local id: 0, noise_sample 30: [-4.92100059  1.99850471]
# Rank: 0, local id: 1, gain_sample 30: [6.29019606 0.95719439 0.64579837 0.92779632]
# Rank: 0, local id: 1, noise_sample 30: [-4.89070018  1.99757378]
# Reached max iterations with fractional norm error 0.001918736292362109.
# Rank: 0, local id: 0, gain_sample 31: [6.31213743 0.41877342 0.26344116 0.05663215]
# Rank: 0, local id: 0, noise_sample 31: [-4.88692818  2.00221775]
# Rank: 0, local id: 1, gain_sample 31: [6.29036563 0.95747446 0.64523295 0.92625365]
# Rank: 0, local id: 1, noise_sample 31: [-5.16887473  1.99841943]
# Reached max iterations with fractional norm error 0.004157761807649234.
# Rank: 0, local id: 0, gain_sample 32: [6.31219693 0.41867172 0.26122515 0.05741764]
# Rank: 0, local id: 0, noise_sample 32: [-5.09591556  2.00336604]
# Rank: 0, local id: 1, gain_sample 32: [6.29033278 0.95702313 0.6465457  0.9277251 ]
# Rank: 0, local id: 1, noise_sample 32: [-5.48738828  1.998285  ]
# Reached max iterations with fractional norm error 0.00235593362091962.
# Rank: 0, local id: 0, gain_sample 33: [6.31194635 0.41895696 0.2622125  0.05924092]
# Rank: 0, local id: 0, noise_sample 33: [-4.9137432   2.00210193]
# Rank: 0, local id: 1, gain_sample 33: [6.290227   0.95741221 0.64545009 0.9260812 ]
# Rank: 0, local id: 1, noise_sample 33: [-4.86213073  1.99128619]
# Reached max iterations with fractional norm error 0.004815139720687001.
# Rank: 0, local id: 0, gain_sample 34: [6.31199614 0.41989658 0.2641769  0.0563811 ]
# Rank: 0, local id: 0, noise_sample 34: [-4.64824646  1.99929337]
# Rank: 0, local id: 1, gain_sample 34: [6.29016903 0.95753906 0.64530592 0.92579388]
# Rank: 0, local id: 1, noise_sample 34: [-4.9402051  2.0022331]
# Reached max iterations with fractional norm error 0.0011408335397729273.
# Rank: 0, local id: 0, gain_sample 35: [6.31172081 0.41831371 0.2639984  0.05644773]
# Rank: 0, local id: 0, noise_sample 35: [-4.68301578  2.00360846]
# Rank: 0, local id: 1, gain_sample 35: [6.2902207  0.95736238 0.64638914 0.92596886]
# Rank: 0, local id: 1, noise_sample 35: [-5.0842795   1.99676201]
# Reached max iterations with fractional norm error 0.003896233293952511.
# Rank: 0, local id: 0, gain_sample 36: [6.31175996 0.42005424 0.26391568 0.05461092]
# Rank: 0, local id: 0, noise_sample 36: [-4.94804152  2.00216439]
# Rank: 0, local id: 1, gain_sample 36: [6.29033446 0.9582809  0.64706302 0.92906958]
# Rank: 0, local id: 1, noise_sample 36: [-5.07652699  1.99932514]
# Reached max iterations with fractional norm error 0.0020968034014516254.
# Rank: 0, local id: 0, gain_sample 37: [6.31177669 0.41946874 0.26414825 0.05802648]
# Rank: 0, local id: 0, noise_sample 37: [-5.20183109  1.999871  ]
# Rank: 0, local id: 1, gain_sample 37: [6.29015842 0.95798613 0.64518609 0.92788874]
# Rank: 0, local id: 1, noise_sample 37: [-4.88296259  2.00229441]
# Reached max iterations with fractional norm error 0.00032401059126877093.
# Rank: 0, local id: 0, gain_sample 38: [6.31136564 0.42042336 0.26244491 0.05685978]
# Rank: 0, local id: 0, noise_sample 38: [-4.82014881  2.00085358]
# Rank: 0, local id: 1, gain_sample 38: [6.29045421 0.95775142 0.64593117 0.92948187]
# Rank: 0, local id: 1, noise_sample 38: [-4.88196248  2.00310433]
# Reached max iterations with fractional norm error 0.004341183065571646.
# Rank: 0, local id: 0, gain_sample 39: [6.31133372 0.42051809 0.26605674 0.05718327]
# Rank: 0, local id: 0, noise_sample 39: [-5.08858351  1.99999965]
# Rank: 0, local id: 1, gain_sample 39: [6.29081189 0.95771777 0.64727231 0.92738052]
# Rank: 0, local id: 1, noise_sample 39: [-5.09620422  1.99579866]
# Reached max iterations with fractional norm error 0.000303306577997741.
# Rank: 0, local id: 0, gain_sample 40: [6.31136349 0.4202541  0.2649787  0.05717628]
# Rank: 0, local id: 0, noise_sample 40: [-5.67941615  2.0020701 ]
# Rank: 0, local id: 1, gain_sample 40: [6.29090389 0.9571006  0.64838282 0.92677707]
# Rank: 0, local id: 1, noise_sample 40: [-4.98822219  1.99980812]
# Reached max iterations with fractional norm error 0.003126663044634627.
# Rank: 0, local id: 0, gain_sample 41: [6.31130072 0.41949317 0.26418556 0.05821701]
# Rank: 0, local id: 0, noise_sample 41: [-4.78711118  1.99628891]
# Rank: 0, local id: 1, gain_sample 41: [6.29060796 0.95757096 0.64615414 0.92564751]
# Rank: 0, local id: 1, noise_sample 41: [-4.94332455  2.0049586 ]
# Reached max iterations with fractional norm error 4.538703793379564e-05.
# Rank: 0, local id: 0, gain_sample 42: [6.3111551  0.41892201 0.26281881 0.05969296]
# Rank: 0, local id: 0, noise_sample 42: [-4.76753074  1.99902826]
# Rank: 0, local id: 1, gain_sample 42: [6.29039149 0.9576994  0.64523329 0.92463369]
# Rank: 0, local id: 1, noise_sample 42: [-4.81772515  2.00160517]
# Reached max iterations with fractional norm error 0.0004744362498105605.
# Rank: 0, local id: 0, gain_sample 43: [6.31108331 0.42068577 0.25995761 0.05675095]
# Rank: 0, local id: 0, noise_sample 43: [-4.87249526  2.00230084]
# Rank: 0, local id: 1, gain_sample 43: [6.28976917 0.95586327 0.64530171 0.92992616]
# Rank: 0, local id: 1, noise_sample 43: [-5.04205817  1.99870067]
# Reached max iterations with fractional norm error 0.0059569387366389705.
# Rank: 0, local id: 0, gain_sample 44: [6.31117108 0.41934467 0.26336916 0.05918812]
# Rank: 0, local id: 0, noise_sample 44: [-4.98432077  1.9985426 ]
# Rank: 0, local id: 1, gain_sample 44: [6.28897059 0.95631063 0.64261222 0.92687092]
# Rank: 0, local id: 1, noise_sample 44: [-5.11037716  2.00058852]
# Reached max iterations with fractional norm error 0.00018703891790196247.
# Rank: 0, local id: 0, gain_sample 45: [6.31115153 0.41822358 0.26398632 0.05864531]
# Rank: 0, local id: 0, noise_sample 45: [-5.03517323  1.99928397]
# Rank: 0, local id: 1, gain_sample 45: [6.28925462 0.95633204 0.64423539 0.92806083]
# Rank: 0, local id: 1, noise_sample 45: [-5.00181576  1.99675646]
# Reached max iterations with fractional norm error 0.00015967341381705561.
# Rank: 0, local id: 0, gain_sample 46: [6.3111826  0.41862671 0.26465445 0.06052423]
# Rank: 0, local id: 0, noise_sample 46: [-4.88689145  1.99828302]
# Rank: 0, local id: 1, gain_sample 46: [6.28940716 0.95648498 0.64548588 0.92664978]
# Rank: 0, local id: 1, noise_sample 46: [-4.77415545  1.99944285]
# Reached max iterations with fractional norm error 0.0037275966330324274.
# Rank: 0, local id: 0, gain_sample 47: [6.31155785 0.41965082 0.26547648 0.05901853]
# Rank: 0, local id: 0, noise_sample 47: [-4.71790925  2.00303688]
# Rank: 0, local id: 1, gain_sample 47: [6.28952955 0.95738468 0.64552462 0.92768939]
# Rank: 0, local id: 1, noise_sample 47: [-4.91576605  1.99803317]
# Reached max iterations with fractional norm error 0.00012387608949163758.
# Rank: 0, local id: 0, gain_sample 48: [6.31172157 0.41999249 0.26527271 0.05791794]
# Rank: 0, local id: 0, noise_sample 48: [-4.95424445  1.99963972]
# Rank: 0, local id: 1, gain_sample 48: [6.28916211 0.95636147 0.64411309 0.9265877 ]
# Rank: 0, local id: 1, noise_sample 48: [-4.83630928  2.00003679]
# Reached max iterations with fractional norm error 0.0013128969709148232.
# Rank: 0, local id: 0, gain_sample 49: [6.31173058 0.42024033 0.26227423 0.05959347]
# Rank: 0, local id: 0, noise_sample 49: [-4.87921765  2.00208309]
# Rank: 0, local id: 1, gain_sample 49: [6.28949901 0.95689592 0.64754074 0.93054725]
# Rank: 0, local id: 1, noise_sample 49: [-4.86055026  1.99952159]
# Reached max iterations with fractional norm error 0.005958631931937446.
# Rank: 0, local id: 0, gain_sample 50: [6.31158456 0.41965194 0.26309505 0.05985934]
# Rank: 0, local id: 0, noise_sample 50: [-4.91319217  1.99891939]
# Rank: 0, local id: 1, gain_sample 50: [6.28908091 0.95711496 0.64179603 0.92567186]
# Rank: 0, local id: 1, noise_sample 50: [-4.5755727   1.99746431]
# Reached max iterations with fractional norm error 0.00020399735369786305.
# Converged in 22 iterations.
# Rank: 0, local id: 0, gain_sample 51: [6.31184392 0.42036995 0.26559486 0.05801034]
# Rank: 0, local id: 0, noise_sample 51: [-4.75826253  1.99743015]
# Rank: 0, local id: 1, gain_sample 51: [6.28891713 0.95807943 0.64329617 0.92361228]
# Rank: 0, local id: 1, noise_sample 51: [-4.65245121  2.00162914]
# Reached max iterations with fractional norm error 0.005337896057644198.
# Rank: 0, local id: 0, gain_sample 52: [6.31181643 0.42073639 0.26659024 0.05885466]
# Rank: 0, local id: 0, noise_sample 52: [-4.73704204  1.99630808]
# Rank: 0, local id: 1, gain_sample 52: [6.2894246  0.95993072 0.64643678 0.92721676]
# Rank: 0, local id: 1, noise_sample 52: [-4.80117716  1.99864969]
# Reached max iterations with fractional norm error 0.0040667607233602614.
# Rank: 0, local id: 0, gain_sample 53: [6.31163882 0.4211434  0.26460124 0.05564843]
# Rank: 0, local id: 0, noise_sample 53: [-4.62462438  1.99985472]
# Rank: 0, local id: 1, gain_sample 53: [6.28876764 0.95872355 0.64484284 0.92590156]
# Rank: 0, local id: 1, noise_sample 53: [-4.80589724  2.00244926]
# Reached max iterations with fractional norm error 0.0004658683487397406.
# Rank: 0, local id: 0, gain_sample 54: [6.31218328 0.42186755 0.26596467 0.05828763]
# Rank: 0, local id: 0, noise_sample 54: [-5.11064934  2.00263203]
# Rank: 0, local id: 1, gain_sample 54: [6.28839147 0.9578276  0.64412388 0.92603529]
# Rank: 0, local id: 1, noise_sample 54: [-4.89207735  1.99945331]
# Reached max iterations with fractional norm error 0.0023058264160878113.
# Rank: 0, local id: 0, gain_sample 55: [6.31215521 0.42170947 0.26433038 0.05627025]
# Rank: 0, local id: 0, noise_sample 55: [-4.96931728  2.00302531]
# Rank: 0, local id: 1, gain_sample 55: [6.28892204 0.95820697 0.64554253 0.92587543]
# Rank: 0, local id: 1, noise_sample 55: [-4.82419578  2.00077101]
# Reached max iterations with fractional norm error 0.0006337005812231392.
# Rank: 0, local id: 0, gain_sample 56: [6.31201045 0.42128234 0.26366624 0.05692274]
# Rank: 0, local id: 0, noise_sample 56: [-4.71299073  2.00092849]
# Rank: 0, local id: 1, gain_sample 56: [6.28899807 0.95803208 0.64530342 0.92847404]
# Rank: 0, local id: 1, noise_sample 56: [-4.8483584   2.00287173]
# Reached max iterations with fractional norm error 0.0003612046030596412.
# Rank: 0, local id: 0, gain_sample 57: [6.31217664 0.42175332 0.26394785 0.05583425]
# Rank: 0, local id: 0, noise_sample 57: [-4.51237764  2.00224815]
# Rank: 0, local id: 1, gain_sample 57: [6.28907447 0.95812878 0.64374689 0.92416445]
# Rank: 0, local id: 1, noise_sample 57: [-4.84625499  2.00054434]
# Reached max iterations with fractional norm error 0.00446606366280441.
# Rank: 0, local id: 0, gain_sample 58: [6.31156187 0.4201652  0.26425556 0.05953013]
# Rank: 0, local id: 0, noise_sample 58: [-4.68421677  2.00320329]
# Rank: 0, local id: 1, gain_sample 58: [6.28916424 0.95985162 0.64377035 0.92382089]
# Rank: 0, local id: 1, noise_sample 58: [-4.89827103  2.00236442]
# Reached max iterations with fractional norm error 0.00020583248479036224.
# Rank: 0, local id: 0, gain_sample 59: [6.31196192 0.42264068 0.26541558 0.05473852]
# Rank: 0, local id: 0, noise_sample 59: [-4.9101893  2.0023161]
# Rank: 0, local id: 1, gain_sample 59: [6.28945562 0.95797446 0.64565035 0.9263289 ]
# Rank: 0, local id: 1, noise_sample 59: [-5.25007578  2.00035127]
# Reached max iterations with fractional norm error 0.005926856193797601.
# Rank: 0, local id: 0, gain_sample 60: [6.31160328 0.42144218 0.26298413 0.05628539]
# Rank: 0, local id: 0, noise_sample 60: [-4.89319265  1.9966287 ]
# Rank: 0, local id: 1, gain_sample 60: [6.28916515 0.95819885 0.64525248 0.92480939]
# Rank: 0, local id: 1, noise_sample 60: [-5.1277556  1.9989086]
# Reached max iterations with fractional norm error 0.004081065622929297.
# Rank: 0, local id: 0, gain_sample 61: [6.31143582 0.42183713 0.26468596 0.05610714]
# Rank: 0, local id: 0, noise_sample 61: [-4.80929309  1.99765407]
# Rank: 0, local id: 1, gain_sample 61: [6.28952953 0.9587506  0.64655626 0.92507685]
# Rank: 0, local id: 1, noise_sample 61: [-4.93795849  1.99704077]
# Reached max iterations with fractional norm error 0.0005056104857672146.
# Rank: 0, local id: 0, gain_sample 62: [6.31144659 0.42166875 0.26585212 0.05602594]
# Rank: 0, local id: 0, noise_sample 62: [-4.83145494  2.0021306 ]
# Rank: 0, local id: 1, gain_sample 62: [6.28927228 0.95710693 0.64572304 0.92420272]
# Rank: 0, local id: 1, noise_sample 62: [-4.74045097  2.00250078]
# Reached max iterations with fractional norm error 0.0024846721897089172.
# Rank: 0, local id: 0, gain_sample 63: [6.3106385  0.42081164 0.26186167 0.05436907]
# Rank: 0, local id: 0, noise_sample 63: [-4.91368365  2.00070402]
# Rank: 0, local id: 1, gain_sample 63: [6.2890714  0.95772032 0.64328177 0.92266484]
# Rank: 0, local id: 1, noise_sample 63: [-4.73854783  2.00276546]
# Reached max iterations with fractional norm error 0.0036702223479979845.
# Rank: 0, local id: 0, gain_sample 64: [6.31054477 0.42089772 0.2622162  0.05790384]
# Rank: 0, local id: 0, noise_sample 64: [-5.12530517  2.00013737]
# Rank: 0, local id: 1, gain_sample 64: [6.28966013 0.95777386 0.64466619 0.9258214 ]
# Rank: 0, local id: 1, noise_sample 64: [-4.68399956  1.99787092]
# Reached max iterations with fractional norm error 0.006207751280060258.
# Converged in 7 iterations.
# Rank: 0, local id: 0, gain_sample 65: [6.31050703 0.42039671 0.26358897 0.0572275 ]
# Rank: 0, local id: 0, noise_sample 65: [-4.85964061  1.99869524]
# Rank: 0, local id: 1, gain_sample 65: [6.2894193  0.95735751 0.64614739 0.92921954]
# Rank: 0, local id: 1, noise_sample 65: [-4.83582964  1.99955978]
# Reached max iterations with fractional norm error 0.0016743543890264374.
# Rank: 0, local id: 0, gain_sample 66: [6.31031368 0.41949603 0.26155067 0.0568274 ]
# Rank: 0, local id: 0, noise_sample 66: [-5.13520163  2.0007883 ]
# Rank: 0, local id: 1, gain_sample 66: [6.2895533  0.95928242 0.64632281 0.9257865 ]
# Rank: 0, local id: 1, noise_sample 66: [-4.80031329  2.00198551]
# Reached max iterations with fractional norm error 0.0002720132877431236.
# Rank: 0, local id: 0, gain_sample 67: [6.31050061 0.41972207 0.26047645 0.05528146]
# Rank: 0, local id: 0, noise_sample 67: [-5.09135401  2.00028194]
# Rank: 0, local id: 1, gain_sample 67: [6.28920262 0.95918885 0.64859919 0.92746887]
# Rank: 0, local id: 1, noise_sample 67: [-4.69803984  1.99743157]
# Reached max iterations with fractional norm error 0.0011843696911204406.
# Rank: 0, local id: 0, gain_sample 68: [6.3100461  0.41938491 0.26073342 0.0542479 ]
# Rank: 0, local id: 0, noise_sample 68: [-5.96104706  1.99996903]
# Rank: 0, local id: 1, gain_sample 68: [6.28902768 0.95792685 0.64678961 0.92804856]
# Rank: 0, local id: 1, noise_sample 68: [-4.83244588  1.99987455]
# Reached max iterations with fractional norm error 0.0040676922381559484.
# Rank: 0, local id: 0, gain_sample 69: [6.30998249 0.41933704 0.26068527 0.05542785]
# Rank: 0, local id: 0, noise_sample 69: [-4.82208375  2.00102939]
# Rank: 0, local id: 1, gain_sample 69: [6.2888725  0.9579367  0.64691611 0.92633279]
# Rank: 0, local id: 1, noise_sample 69: [-4.91103819  2.00172757]
# Reached max iterations with fractional norm error 0.0003535365420028346.
# Rank: 0, local id: 0, gain_sample 70: [6.3100454  0.41937976 0.26271323 0.0566657 ]
# Rank: 0, local id: 0, noise_sample 70: [-4.87481133  2.00012852]
# Rank: 0, local id: 1, gain_sample 70: [6.28895704 0.9579468  0.64633045 0.92687841]
# Rank: 0, local id: 1, noise_sample 70: [-5.23903586  2.00293079]
# Reached max iterations with fractional norm error 0.00021530466580145884.
# Rank: 0, local id: 0, gain_sample 71: [6.31018052 0.42033292 0.26538771 0.05643197]
# Rank: 0, local id: 0, noise_sample 71: [-4.86350092  2.00112826]
# Rank: 0, local id: 1, gain_sample 71: [6.28861404 0.95854572 0.64587028 0.92789703]
# Rank: 0, local id: 1, noise_sample 71: [-4.87279573  1.99886761]
# Reached max iterations with fractional norm error 0.0015208164584918425.
# Rank: 0, local id: 0, gain_sample 72: [6.3102529  0.42151055 0.26430766 0.05736208]
# Rank: 0, local id: 0, noise_sample 72: [-4.94589919  2.00247064]
# Rank: 0, local id: 1, gain_sample 72: [6.28823436 0.95945453 0.6455495  0.92507553]
# Rank: 0, local id: 1, noise_sample 72: [-4.91026539  2.00046885]
# Reached max iterations with fractional norm error 0.0036295374882482187.
# Rank: 0, local id: 0, gain_sample 73: [6.309892   0.42071486 0.26271269 0.05767075]
# Rank: 0, local id: 0, noise_sample 73: [-5.55641784  2.00166485]
# Rank: 0, local id: 1, gain_sample 73: [6.28830019 0.95962485 0.64608635 0.92821054]
# Rank: 0, local id: 1, noise_sample 73: [-4.90277925  1.99994943]
# Reached max iterations with fractional norm error 0.0009167914385886738.
# Rank: 0, local id: 0, gain_sample 74: [6.30990144 0.42068079 0.26261255 0.05807031]
# Rank: 0, local id: 0, noise_sample 74: [-5.94656813  2.00256525]
# Rank: 0, local id: 1, gain_sample 74: [6.28759791 0.95799208 0.64341552 0.92760795]
# Rank: 0, local id: 1, noise_sample 74: [-4.97953653  2.00158033]
# Reached max iterations with fractional norm error 0.00010152665087609021.
# Rank: 0, local id: 0, gain_sample 75: [6.30997393 0.41983914 0.26252894 0.05836199]
# Rank: 0, local id: 0, noise_sample 75: [-4.808544    2.00091867]
# Rank: 0, local id: 1, gain_sample 75: [6.28815928 0.95831675 0.64423931 0.92941139]
# Rank: 0, local id: 1, noise_sample 75: [-4.9302514  1.9989411]
# Reached max iterations with fractional norm error 0.00027368905615844186.
# Rank: 0, local id: 0, gain_sample 76: [6.30984237 0.41892223 0.26448211 0.05599773]
# Rank: 0, local id: 0, noise_sample 76: [-4.933212    1.99884548]
# Rank: 0, local id: 1, gain_sample 76: [6.2882057  0.95779599 0.64510874 0.92952799]
# Rank: 0, local id: 1, noise_sample 76: [-4.73931178  2.00069011]
# Reached max iterations with fractional norm error 0.0036706280464750113.
# Rank: 0, local id: 0, gain_sample 77: [6.30940579 0.41935604 0.26293577 0.05774801]
# Rank: 0, local id: 0, noise_sample 77: [-5.01588027  2.00044776]
# Rank: 0, local id: 1, gain_sample 77: [6.28856129 0.95758988 0.64790876 0.93047484]
# Rank: 0, local id: 1, noise_sample 77: [-4.87980858  2.00379596]
# Reached max iterations with fractional norm error 0.00030455227231240454.
# Rank: 0, local id: 0, gain_sample 78: [6.30940152 0.42039132 0.26239222 0.0570662 ]
# Rank: 0, local id: 0, noise_sample 78: [-4.77785593  1.99871178]
# Rank: 0, local id: 1, gain_sample 78: [6.28815984 0.95705708 0.64689755 0.92920084]
# Rank: 0, local id: 1, noise_sample 78: [-4.68206528  2.0027764 ]
# Reached max iterations with fractional norm error 0.00016421800783977383.
# Rank: 0, local id: 0, gain_sample 79: [6.30911754 0.42055774 0.26430895 0.05622618]
# Rank: 0, local id: 0, noise_sample 79: [-4.75720521  1.99734325]
# Rank: 0, local id: 1, gain_sample 79: [6.28742641 0.95730975 0.64744776 0.92571672]
# Rank: 0, local id: 1, noise_sample 79: [-4.46572561  1.99700723]
# Reached max iterations with fractional norm error 0.0015459444766443007.
# Rank: 0, local id: 0, gain_sample 80: [6.30851731 0.42055496 0.26487718 0.05864679]
# Rank: 0, local id: 0, noise_sample 80: [-4.86058014  1.99830485]
# Rank: 0, local id: 1, gain_sample 80: [6.28746218 0.95667856 0.64809507 0.92450365]
# Rank: 0, local id: 1, noise_sample 80: [-4.71420984  2.00304068]
# Reached max iterations with fractional norm error 0.0005771962036044099.
# Rank: 0, local id: 0, gain_sample 81: [6.30813608 0.42065428 0.26461172 0.05954   ]
# Rank: 0, local id: 0, noise_sample 81: [-4.59404086  2.00147926]
# Rank: 0, local id: 1, gain_sample 81: [6.28812578 0.95736384 0.64856682 0.92953694]
# Rank: 0, local id: 1, noise_sample 81: [-4.85187134  1.99866951]
# Reached max iterations with fractional norm error 0.0005311110949179977.
# Rank: 0, local id: 0, gain_sample 82: [6.30821516 0.41976944 0.2630099  0.05555809]
# Rank: 0, local id: 0, noise_sample 82: [-4.76984348  2.00175282]
# Rank: 0, local id: 1, gain_sample 82: [6.28782357 0.95720535 0.64652066 0.92663482]
# Rank: 0, local id: 1, noise_sample 82: [-4.76320355  1.99795937]
# Reached max iterations with fractional norm error 5.342128339310702e-05.
# Rank: 0, local id: 0, gain_sample 83: [6.30816465 0.42055203 0.26240159 0.05468734]
# Rank: 0, local id: 0, noise_sample 83: [-4.14345253  2.00071016]
# Rank: 0, local id: 1, gain_sample 83: [6.28869675 0.95975036 0.64574949 0.92849286]
# Rank: 0, local id: 1, noise_sample 83: [-4.93936146  1.99920422]
# Reached max iterations with fractional norm error 0.0008895642497544686.
# Rank: 0, local id: 0, gain_sample 84: [6.3086104  0.4170681  0.26561306 0.05816742]
# Rank: 0, local id: 0, noise_sample 84: [-4.36654109  1.99836695]
# Rank: 0, local id: 1, gain_sample 84: [6.28847322 0.95931215 0.64508857 0.92792036]
# Rank: 0, local id: 1, noise_sample 84: [-4.96710505  1.99984223]
# Reached max iterations with fractional norm error 0.0006863060077729266.
# Rank: 0, local id: 0, gain_sample 85: [6.30791495 0.42090902 0.26199204 0.06003651]
# Rank: 0, local id: 0, noise_sample 85: [-4.6721875   2.00148249]
# Rank: 0, local id: 1, gain_sample 85: [6.28866967 0.95926575 0.64735586 0.92802809]
# Rank: 0, local id: 1, noise_sample 85: [-4.980782    2.00117444]
# Reached max iterations with fractional norm error 0.0020199645954531342.
# Rank: 0, local id: 0, gain_sample 86: [6.30768752 0.42160438 0.26055828 0.05695483]
# Rank: 0, local id: 0, noise_sample 86: [-4.94224199  2.00077332]
# Rank: 0, local id: 1, gain_sample 86: [6.28860083 0.95932356 0.64741171 0.92764652]
# Rank: 0, local id: 1, noise_sample 86: [-5.27827646  1.99821063]
# Reached max iterations with fractional norm error 0.0008848681654587109.
# Rank: 0, local id: 0, gain_sample 87: [6.30811617 0.42085561 0.26514191 0.05689515]
# Rank: 0, local id: 0, noise_sample 87: [-4.77069198  1.99841091]
# Rank: 0, local id: 1, gain_sample 87: [6.28869061 0.95825649 0.64706954 0.92650591]
# Rank: 0, local id: 1, noise_sample 87: [-4.77399587  2.00643083]
# Reached max iterations with fractional norm error 0.0029223629082040666.
# Rank: 0, local id: 0, gain_sample 88: [6.30826798 0.4226761  0.26550817 0.05234973]
# Rank: 0, local id: 0, noise_sample 88: [-4.71136172  1.99828523]
# Rank: 0, local id: 1, gain_sample 88: [6.2887176  0.95956697 0.64921233 0.92692441]
# Rank: 0, local id: 1, noise_sample 88: [-4.60676532  2.00411996]
# Reached max iterations with fractional norm error 0.0030244411548939966.
# Rank: 0, local id: 0, gain_sample 89: [6.30795875 0.42229732 0.26325055 0.05633344]
# Rank: 0, local id: 0, noise_sample 89: [-4.97144285  1.99910898]
# Rank: 0, local id: 1, gain_sample 89: [6.28946741 0.96010516 0.64743673 0.93100289]
# Rank: 0, local id: 1, noise_sample 89: [-4.88691559  2.00185358]
# Reached max iterations with fractional norm error 0.0004986527284508291.
# Rank: 0, local id: 0, gain_sample 90: [6.30794548 0.42134505 0.26320582 0.05977931]
# Rank: 0, local id: 0, noise_sample 90: [-4.82918525  1.99986609]
# Rank: 0, local id: 1, gain_sample 90: [6.28953814 0.96111788 0.64853134 0.92827693]
# Rank: 0, local id: 1, noise_sample 90: [-4.88569224  2.00114258]
# Reached max iterations with fractional norm error 0.002376760056154823.
# Rank: 0, local id: 0, gain_sample 91: [6.30797286 0.42244654 0.26451528 0.05457365]
# Rank: 0, local id: 0, noise_sample 91: [-4.67471152  1.99938794]
# Rank: 0, local id: 1, gain_sample 91: [6.28936731 0.96010831 0.64647359 0.9260793 ]
# Rank: 0, local id: 1, noise_sample 91: [-5.58195898  2.00101852]
# Reached max iterations with fractional norm error 0.00037873919167146685.
# Rank: 0, local id: 0, gain_sample 92: [6.30802832 0.42114785 0.26214131 0.05834424]
# Rank: 0, local id: 0, noise_sample 92: [-4.72474948  2.00137658]
# Rank: 0, local id: 1, gain_sample 92: [6.28926242 0.9599689  0.64572634 0.925774  ]
# Rank: 0, local id: 1, noise_sample 92: [-4.80305425  1.99870782]
# Reached max iterations with fractional norm error 5.499263723666302e-05.
# Rank: 0, local id: 0, gain_sample 93: [6.30817406 0.41866392 0.25967021 0.05747497]
# Rank: 0, local id: 0, noise_sample 93: [-4.85673632  1.99756746]
# Rank: 0, local id: 1, gain_sample 93: [6.28956052 0.96133921 0.64679012 0.92704884]
# Rank: 0, local id: 1, noise_sample 93: [-4.69161761  1.99833128]
# Reached max iterations with fractional norm error 0.0005735510626130184.
# Rank: 0, local id: 0, gain_sample 94: [6.30798519 0.4207746  0.261613   0.05672343]
# Rank: 0, local id: 0, noise_sample 94: [-4.87332162  2.00097412]
# Rank: 0, local id: 1, gain_sample 94: [6.28930006 0.95970265 0.64843001 0.92449007]
# Rank: 0, local id: 1, noise_sample 94: [-4.87969376  1.99958975]
# Reached max iterations with fractional norm error 0.002859314352752614.
# Rank: 0, local id: 0, gain_sample 95: [6.30777139 0.42015764 0.26183833 0.05702518]
# emcee: Exception while calling your likelihood function:
#   params: [-4.94422877  1.94825735]
#   args: []
#   kwargs: {}
#   exception:
# Traceback (most recent call last):
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/emcee/ensemble.py", line 640, in __call__
#     return self.f(x, *self.args, **self.kwargs)
#            ~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zzhang/Workspace/flicker/notebooks/../hydra_TOD/mcmc_sampler.py", line 97, in log_prob
#     return log_like(params) + prior_function(params)
#            ~~~~~~~~^^^^^^^^
#   File "/Users/zzhang/Workspace/flicker/notebooks/../hydra_TOD/noise_sampler_fixed_fc.py", line 66, in log_like
#     corr_list = flicker_cov_vec(tau_list, 10.**logf0, 10.**logfc, alpha,  white_n_variance=wnoise_var)
#   File "/Users/zzhang/Workspace/flicker/notebooks/../hydra_TOD/flicker_model.py", line 106, in flicker_cov_vec
#     result[1:] = flicker_corr_vec(tau_list[1:], f0, fc, alpha)
#                  ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zzhang/Workspace/flicker/notebooks/../hydra_TOD/flicker_model.py", line 99, in flicker_corr_vec
#     result = aux_int_v2(mu, theta_c)
#   File "/Users/zzhang/Workspace/flicker/notebooks/../hydra_TOD/flicker_model.py", line 61, in aux_int_v2
#     aux = my_gamma_inc(mu, u_list) # This is actually the same as gammainc(mu, 1j * u)
#   File "/Users/zzhang/Workspace/flicker/notebooks/../hydra_TOD/flicker_model.py", line 40, in my_gamma_inc
#     results = np.array(mpiutil.local_parallel_func(_integral_single, R_vals))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zzhang/Workspace/flicker/notebooks/../hydra_TOD/mpiutil.py", line 78, in local_parallel_func
#     return parallel(delayed(func)(item) for item in input_list)
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/joblib/parallel.py", line 2007, in __call__
#     return output if self.return_generator else list(output)
#                                                 ~~~~^^^^^^^^
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/joblib/parallel.py", line 1650, in _get_outputs
#     yield from self._retrieve()
#   File "/opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/joblib/parallel.py", line 1762, in _retrieve
#     time.sleep(0.01)
#     ~~~~~~~~~~^^^^^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 4
#       1 from full_Gibbs_sampler import full_Gibbs_sampler_multi_TODS_v2
#       3 Tsys_samples, all_gain_samples, all_noise_samples = \
# ----> 4     full_Gibbs_sampler_multi_TODS_v2([TOD_setting, TOD_rising],
#       5                                     [t_list, t_list],
#       6                                     [gain_proj, gain_proj],
#       7                                     [Tsky_operator_setting, Tsky_operator_rising],
#       8                                     [nd_rec_operator, nd_rec_operator],
#       9                                     init_Tsys_params,
#      10                                     init_noise_params,
#      11                                     [logfc, logfc],
#      12                                     num_Jeffrey=False,
#      13                                     wnoise_var=2.5e-6,
#      14                                     Tsky_prior_cov_inv=Tsky_prior_cov_inv,
#      15                                     Tsky_prior_mean=sky_params,
#      16                                     local_Trec_prior_cov_inv_list=Trec_prior_cov_inv,
#      17                                     local_Trec_prior_mean_list=[nd_rec_params, nd_rec_params],
#      18                                     local_gain_prior_cov_inv_list=[gain_prior_cov_inv,gain_prior_cov_inv],
#      19                                     local_gain_prior_mean_list=[gain_prior_mean,gain_prior_mean],
#      20                                     local_noise_prior_func_list=[log_prior_noise, log_prior_noise],
#      21                                     n_samples=300,
#      22                                     tol=1e-12)
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/full_Gibbs_sampler.py:457, in full_Gibbs_sampler_multi_TODS_v2(local_TOD_list, local_t_lists, local_gain_operator_list, local_Tsky_operator_list, local_Trec_operator_list, init_Tsys_params, init_noise_params, local_logfc_list, num_Jeffrey, wnoise_var, Tsky_prior_cov_inv, Tsky_prior_mean, local_Trec_prior_cov_inv_list, local_Trec_prior_mean_list, local_gain_prior_cov_inv_list, local_gain_prior_mean_list, local_noise_prior_func_list, log_linear_gain, n_samples, tol, linear_solver, Est_mode, root)
#     454 print("Rank: {}, local id: {}, gain_sample {}: {}".format(rank, di, si, gain_sample))
#     456 # Sample noise parameters
# --> 457 noise_sample = flicker_noise_sampler(TOD,
#     458                                     t_list,
#     459                                     gains,
#     460                                     Tsys,
#     461                                     init_noise_params, # using the input init_noise_params as fixed initial point for MCMC sampling
#     462                                     logfc,
#     463                                     n_samples=num_sample,
#     464                                     wnoise_var=wnoise_var,
#     465                                     prior_func=local_noise_prior_func_list[di],
#     466                                     num_Jeffrey=num_Jeffrey)
#     467 local_noise_samples[di, si, :] = noise_sample
#     468 print("Rank: {}, local id: {}, noise_sample {}: {}".format(rank, di, si, noise_sample))
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/noise_sampler_fixed_fc.py:93, in flicker_noise_sampler(TOD, t_list, gains, Tsys, init_params, logfc, n_samples, wnoise_var, prior_func, num_Jeffrey, boundaries)
#      89     boundaries = [[-6, -1. ], [1.1, 4.]]  # Default boundaries
#      91 log_likeli = flicker_likeli_func(t_list, TOD, gains, Tsys, logfc, wnoise_var=wnoise_var, boundaries=boundaries)
# ---> 93 return mcmc_sampler(log_likeli,
#      94                     init_params,
#      95                     p_std=0.2,
#      96                     nsteps=50,  # steps for each chain
#      97                     n_samples=n_samples,
#      98                     prior_func=prior_func,
#      99                     num_Jeffrey=num_Jeffrey,
#     100                     return_sampler=False)
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/mcmc_sampler.py:110, in mcmc_sampler(log_like, p_guess, p_std, nsteps, n_samples, prior_func, num_Jeffrey, return_sampler)
#     108 for i in range(n_rounds):
#     109     logging.info(f'Running MCMC sampler for the {i+1}th time...')
# --> 110     sampler.run_mcmc(p0, nsteps, progress=False)
#     112     try: # Estimate the autocorrelation time
#     113         # Catch warnings related to autocorrelation time estimation
#     114         with warnings.catch_warnings():
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/emcee/ensemble.py:450, in EnsembleSampler.run_mcmc(self, initial_state, nsteps, **kwargs)
#     447     initial_state = self._previous_state
#     449 results = None
# --> 450 for results in self.sample(initial_state, iterations=nsteps, **kwargs):
#     451     pass
#     453 # Store so that the ``initial_state=None`` case will work
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/emcee/ensemble.py:409, in EnsembleSampler.sample(self, initial_state, log_prob0, rstate0, blobs0, iterations, tune, skip_initial_state_check, thin_by, thin, store, progress, progress_kwargs)
#     406 move = self._random.choice(self._moves, p=self._weights)
#     408 # Propose
# --> 409 state, accepted = move.propose(model, state)
#     410 state.random_state = self.random_state
#     412 if tune:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/emcee/moves/red_blue.py:93, in RedBlueMove.propose(self, model, state)
#      90 q, factors = self.get_proposal(s, c, model.random)
#      92 # Compute the lnprobs of the proposed position.
# ---> 93 new_log_probs, new_blobs = model.compute_log_prob_fn(q)
#      95 # Loop over the walkers and update them accordingly.
#      96 for i, (j, f, nlp) in enumerate(
#      97     zip(all_inds[S1], factors, new_log_probs)
#      98 ):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/emcee/ensemble.py:496, in EnsembleSampler.compute_log_prob(self, coords)
#     494     else:
#     495         map_func = map
# --> 496     results = list(map_func(self.log_prob_fn, p))
#     498 try:
#     499     # perhaps log_prob_fn returns blobs?
#     500
#    (...)    504     # l is a length-1 array, np.array([1.234]). In that case blob
#     505     # will become an empty list.
#     506     blob = [l[1:] for l in results if len(l) > 1]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/emcee/ensemble.py:640, in _FunctionWrapper.__call__(self, x)
#     638 def __call__(self, x):
#     639     try:
# --> 640         return self.f(x, *self.args, **self.kwargs)
#     641     except:  # pragma: no cover
#     642         import traceback
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/mcmc_sampler.py:97, in mcmc_sampler.<locals>.log_prob(params)
#      96 def log_prob(params):
# ---> 97     return log_like(params) + prior_function(params)
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/noise_sampler_fixed_fc.py:66, in flicker_likeli_func.<locals>.log_like(params)
#      64 if logf0 < boundaries[0][0] or logf0 > boundaries[0][1] or alpha < boundaries[1][0] or alpha > boundaries[1][1]:
#      65     return -np.inf  # Log of zero for invalid regions
# ---> 66 corr_list = flicker_cov_vec(tau_list, 10.**logf0, 10.**logfc, alpha,  white_n_variance=wnoise_var)
#      67 return log_likeli(corr_list, dvec)
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/flicker_model.py:106, in flicker_cov_vec(tau_list, f0, fc, alpha, white_n_variance)
#     104 result = np.zeros_like(tau_list)
#     105 result[0] = fc/np.pi * (f0/fc)**alpha  / (alpha-1) + white_n_variance
# --> 106 result[1:] = flicker_corr_vec(tau_list[1:], f0, fc, alpha)
#     107 return result.astype(np.float64)
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/flicker_model.py:99, in flicker_corr_vec(taus, f0, fc, alpha)
#      96 mu = 1-alpha
#      97 # result = np.array([aux_calculation(theta_c[i], mu)
#      98 #                                               for i in range(len(taus))])
# ---> 99 result = aux_int_v2(mu, theta_c)
#     100 return result * norm
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/flicker_model.py:61, in aux_int_v2(mu, u_list)
#      59 def aux_int_v2(mu, u_list):
#      60     # Exp[- ( Pi / 2 ) I Mu]  Gamma[Mu, I  u]
# ---> 61     aux = my_gamma_inc(mu, u_list) # This is actually the same as gammainc(mu, 1j * u)
#      62     cos_ang, sin_ang = np.cos(np.pi/2 * mu), np.sin(np.pi/2 * mu)
#      63     result = aux.real*cos_ang + aux.imag*sin_ang
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/flicker_model.py:40, in my_gamma_inc(z, R_vals, epsabs, epsrel, para_run)
#      38 # Or Parallelize the function:
#      39 if para_run:
# ---> 40     results = np.array(mpiutil.local_parallel_func(_integral_single, R_vals))
#      41     # Return scalar if input was scalar
#      42     return results[0] if results.size == 1 else results
#
# File ~/Workspace/flicker/notebooks/../hydra_TOD/mpiutil.py:78, in local_parallel_func(func, input_list, single_arg)
#      76 with local_parallel_pool as parallel:
#      77     if single_arg:
# ---> 78         return parallel(delayed(func)(item) for item in input_list)
#      79     else: # multiple inputs for func
#      80         return parallel(delayed(func)(*item) for item in input_list)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/TOD/lib/python3.13/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %% [markdown]
# #### Visualize the Tsky samples

# %%
# First, save the samples as npy files..

np.save("outputs/sim2/Tsys_samples.npy", Tsys_samples)
np.save("outputs/sim2/gain_samples.npy", np.concatenate(all_gain_samples, axis=0))
np.save("outputs/sim2/noise_samples.npy", np.concatenate(all_noise_samples, axis=0))

# %%
# Read the saved samples
import numpy as np
Tsys_samples = np.load('outputs/sim2/Tsys_samples.npy')

# %%
num_pixels = len(pixel_indices)
Tsky_samples = Tsys_samples[:, :num_pixels]
Tmean = np.mean(Tsky_samples, axis=0)
Tstd = np.std(Tsky_samples, axis=0)

NPIX = hp.nside2npix(nside)

true_map = np.zeros(NPIX, dtype=float)
sample_mean_map = np.zeros(NPIX, dtype=float)
sample_std_map = np.zeros(NPIX, dtype=float)

true_map[pixel_indices] = sky_params
sample_mean_map[pixel_indices] = Tmean
sample_std_map[pixel_indices] = Tstd

# %%
def view_patch_map(map, pixel_indices):
    # Create a new map with just the patch (other pixels set to UNSEEN)
    patch_only_map = np.full(len(map), hp.UNSEEN)
    patch_only_map[pixel_indices] = map[pixel_indices]
    return patch_only_map

# %%
# Get pixel coordinates
theta, phi = hp.pix2ang(nside, pixel_indices)
lon, lat = np.degrees(phi), 90 - np.degrees(theta)
lon_center, lat_center = np.median(lon), np.median(lat)

# Calculate appropriate zoom/resolution
patch_size = 100  # Add 20% margin
res = patch_size / 20  # Adjust resolution based on patch size

# %%
sky_min = np.min(sky_params)
sky_max = np.max(sky_params)

# %%
patch_true_map = view_patch_map(true_map, pixel_indices)

hp.gnomview(patch_true_map, rot=(lon_center, lat_center), 
           xsize=520, ysize=350, reso=res, 
           title=" ", 
           unit="K", cmap='jet', min=sky_min, max=sky_max,
           #notext=True,
           coord=['C'], 
           cbar=True, notext=False, badcolor='gray')
#plt.grid(True)
hp.graticule(dpar=10, dmer=10, coord=['C'], local=True)  
#plt.grid(color='gray', linestyle=':', alpha=0.5)  # Custom grid style
plt.gca().set_facecolor('gray')  # Set background to white
plt.savefig('outputs/sim2/true_map.pdf', bbox_inches='tight', 
            pad_inches=0.1)

# %%
patch_mean_map = view_patch_map(sample_mean_map, pixel_indices)

hp.gnomview(patch_mean_map, rot=(lon_center, lat_center), 
           xsize=520, ysize=350, reso=res, title=" ", 
           unit="K", cmap='jet', min=10, max=35,
           #notext=True,
           coord=['C'], 
           cbar=True, notext=False, badcolor='gray')
#plt.grid(True)
hp.graticule(dpar=10, dmer=10, coord=['C'], local=True)  
#plt.grid(color='gray', linestyle=':', alpha=0.5)  # Custom grid style
plt.gca().set_facecolor('gray')  # Set background to white
plt.savefig("outputs/sim2/mean_map.pdf", bbox_inches='tight', 
            pad_inches=0.1)

# %%
patch_error_map = view_patch_map(sample_mean_map-true_map, pixel_indices)
# plt.figure(figsize=(10, 6))
hp.gnomview(patch_error_map, rot=(lon_center, lat_center), 
           xsize=520, ysize=350, reso=res, title=" ", 
           unit="K", cmap='RdBu_r', min=-2.8, max=2.8,
           #notext=True,
           coord=['C'], 
           cbar=True, notext=False,
           badcolor='gray')
#plt.grid(True)
hp.graticule(dpar=10, dmer=10, coord=['C'], local=True)  
#plt.grid(color='gray', linestyle=':', alpha=0.5)  # Custom grid style
plt.gca().set_facecolor('gray')  # Set background to white
plt.savefig("outputs/sim2/error_map_multi_TOD.pdf", bbox_inches='tight', 
            pad_inches=0.1)

# %%
patch_std_map = view_patch_map(sample_std_map, pixel_indices)



hp.gnomview(patch_std_map, rot=(lon_center, lat_center), 
           xsize=520, ysize=350, reso=res, title=None, 
           unit="K", cmap='jet', 
           notext=False,
           coord=['C'], 
           cbar=True, 
           badcolor='gray',
           #sub=(2, 1, 1),  # Proper subplot specification
           #margins=(0.05, 0.15, 0.05, 0.15)
           )
#plt.grid(True)
hp.graticule(dpar=10, dmer=10, coord=['C'], local=True)  
#plt.grid(color='gray', linestyle=':', alpha=0.5)  # Custom grid style
plt.gca().set_facecolor('gray')  # Set background to white
plt.savefig("outputs/sim2/std_map_multi_TOD.pdf", bbox_inches='tight', 
            pad_inches=0.1)

# %%
# # ---- Plot results ----
# # Generate a 2D plot of (RA, Dec) coordinates
# plt.figure(figsize=(12, 6))
# plt.scatter(equatorial_coords_setting.ra, equatorial_coords_setting.dec)
# plt.scatter(equatorial_coords_rising.ra, equatorial_coords_rising.dec)
# plt.xlabel("Right Ascension (degrees)")
# plt.ylabel("Declination (degrees)")
# plt.title("Sky Coordinates at Different Times")
# plt.show()

# %% [markdown]
# ### Other components

# %%
gain_samples = np.load("outputs/sim2/gain_samples.npy")

# %%
gain_samples.shape

# %%
view_samples()

# %% [markdown]
# gain_samples = np.load("outputs/sim2/gain_samples.npy")
